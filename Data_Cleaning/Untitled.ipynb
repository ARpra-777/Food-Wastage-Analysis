# %%
import pandas as pd

# %%
table = pd.read_html("https://en.wikipedia.org/wiki/List_of_countries_by_GDP_(PPP)_per_capita")

# %%
df = table[1]

# %%
df.to_csv("GDPPC.csv")

# %%
df = pd.read_csv("GDPPC.csv")
df2 = pd.read_csv("Food Waste data and research - by country.csv")

# %%
df.head()
# Out:
#          Country UN Region IMF_Estimate  Year WB_Estimate Year.1  \
# 0        Ireland    Europe       145196  2023      126905   2022
# 1     Luxembourg    Europe       142490  2023      142214   2022
# 2  Liechtenstein    Europe            —     —           —      —
# 3      Singapore      Asia       133895  2023      127565   2022
# 4          Qatar      Asia       124834  2023      114648   2022
#
#    CIA_Estimate Year.2
# 0        102500   2021
# 1        115700   2021
# 2        139100   2009
# 3        106000   2021
# 4         92200   2021

# %%
df2.head()
# Out:
#        Country  combined figures (kg/capita/year)  \
# 0  Afghanistan                                126
# 1      Albania                                127
# 2      Algeria                                135
# 3      Andorra                                123
# 4       Angola                                144
#
#    Household estimate (kg/capita/year)  Household estimate (tonnes/year)  \
# 0                                   82                           3109153
# 1                                   83                            238492
# 2                                   91                           3918529
# 3                                   84                              6497
# 4                                  100                           3169523
#
#    Retail estimate (kg/capita/year)  Retail estimate (tonnes/year)  \
# 0                                16                         594982
# 1                                16                          45058
# ...

# %%
df3 = df2.merge(df, on='Country', how='left')

# %%
df3.head()
# Out:
#        Country  combined figures (kg/capita/year)  \
# 0  Afghanistan                                126
# 1      Albania                                127
# 2      Algeria                                135
# 3      Andorra                                123
# 4       Angola                                144
#
#    Household estimate (kg/capita/year)  Household estimate (tonnes/year)  \
# 0                                   82                           3109153
# 1                                   83                            238492
# 2                                   91                           3918529
# 3                                   84                              6497
# 4                                  100                           3169523
#
#    Retail estimate (kg/capita/year)  Retail estimate (tonnes/year)  \
# 0                                16                         594982
# 1                                16                          45058
# ...

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 214 entries, 0 to 213
# Data columns (total 16 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   Country                                 214 non-null    object
#  1   combined figures (kg/capita/year)       214 non-null    int64
#  2   Household estimate (kg/capita/year)     214 non-null    int64
#  3   Household estimate (tonnes/year)        214 non-null    int64
#  4   Retail estimate (kg/capita/year)        214 non-null    int64
#  5   Retail estimate (tonnes/year)           214 non-null    int64
#  6   Food service estimate (kg/capita/year)  214 non-null    int64
#  7   Food service estimate (tonnes/year)     214 non-null    int64
#  8   Region                                  214 non-null    object
#  9   UN Region                               189 non-null    object
# ...

# %%
df3.to_csv("fin_v0.csv")

# %%
table2 = pd.read_html("https://www.worldometers.info/world-population/population-by-country/")

# %%
table2[0]
# Out:
#        # Country (or dependency)  Population (2023) Yearly Change  Net Change  \
# 0      1                   India         1428627663        0.81 %    11454490
# 1      2                   China         1425671352       -0.02 %     -215985
# 2      3           United States          339996563        0.50 %     1706706
# 3      4               Indonesia          277534122        0.74 %     2032783
# 4      5                Pakistan          240485658        1.98 %     4660796
# ..   ...                     ...                ...           ...         ...
# 229  230              Montserrat               4386       -0.09 %          -4
# 230  231        Falkland Islands               3791        0.29 %          11
# 231  232                    Niue               1935        0.05 %           1
# 232  233                 Tokelau               1893        1.18 %          22
# 233  234                Holy See                518        1.57 %           8
#
# ...

# %%
df4 = table2[0]

# %%
df4.to_csv("Pop.csv")

# %%
df4 = pd.read_csv("Pop.csv")

# %%
df3 = pd.read_csv("fin_v0.csv")

# %%
df5 = df3.merge(df4, on='Country', how='left')

# %%
df5.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 214 entries, 0 to 213
# Data columns (total 13 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   Unnamed: 0                              214 non-null    int64
#  1   Country                                 214 non-null    object
#  2   combined figures (kg/capita/year)       214 non-null    int64
#  3   Household estimate (kg/capita/year)     214 non-null    int64
#  4   Household estimate (tonnes/year)        214 non-null    int64
#  5   Retail estimate (kg/capita/year)        214 non-null    int64
#  6   Retail estimate (tonnes/year)           214 non-null    int64
#  7   Food service estimate (kg/capita/year)  214 non-null    int64
#  8   Food service estimate (tonnes/year)     214 non-null    int64
#  9   Region                                  214 non-null    object
# ...

# %%
df5.to_csv("fin_v1.csv")

# %%
table3 = pd.read_html("https://www.macrotrends.net/countries/ranking/hunger-statistics")
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_29012/1788796666.py in <module>
# ----> 1 table3 = pd.read_html("https://www.macrotrends.net/countries/ranking/hunger-statistics")
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\html.py in read_html(io, match, flavor, header, index_col, skiprows, attrs, parse_dates, thousands, encoding, decimal, converters, na_values, keep_default_na, displayed_only)
#    1096     io = stringify_path(io)
#    1097
# -> 1098     return _parse(
#    1099         flavor=flavor,
#    1100         io=io,
#
# ...
